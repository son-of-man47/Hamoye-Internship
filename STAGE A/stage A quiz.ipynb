# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = r"C:/Users/IROANYA/Documents/DATA ANALYSIS FILES/hamoye files/FoodBalanceSheets_E_Africa_NOFLAG.csv"

# %%
dt = pd.read_csv(file, encoding = "unicode_escape")
df = dt.copy()
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60938    False
# 60939    False
# 60940    False
# 60941    False
# 60942    False
# Length: 60943, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df["Area"].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df["Item"].unique()
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...

# %%
df["Element"].unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
df["Area"].nunique()
# Out:
# 49

# %%
df["Area Code"].nunique()
# Out:
# 49

# %%
df.head(20)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df["Element"].nunique()
# Out:
# 18

# %%
df.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# Y2018           0
# dtype: int64

# %%
a_fat = df.groupby("Item")[["Y2014", "Y2017"]].sum()
# a_fat[(a_fat.Item) == "Animal fats"]
a_fat
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2329.00    2299.00
# Alcoholic Beverages  102391.11   95572.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10197.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157749.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4494.36    4172.02
# Yams                 200396.96  229172.59
#
# [119 rows x 2 columns]

# %%
import_q = df.groupby("Element")[["Y2014", "Y2015", "Y2016", "Y2017", "Y2018"]].sum()
import_q
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996714.35  2021472.55  2044822.70
# Export Quantity                          149683.64   157195.47   151372.46
# Fat supply quantity (g/capita/day)        10225.52    10234.82    10101.07
# Feed                                     216906.89   224998.22   228949.65
# Food                                    1212296.49  1232283.10  1246953.17
# Food supply (kcal/capita/day)            454248.00   453365.00   451790.00
# Food supply quantity (kg/capita/yr)       49648.98    49341.68    48982.15
# Import Quantity                          274037.48   266841.46   286393.78
# Losses                                   153222.00   155438.00   157787.00
# Other uses (non-food)                     78656.13    66151.41    69519.68
# Processing                               282905.00   287917.00   280618.00
# ...

# %%
y18 = df[["Element", "Y2018"]]
hi = y18.groupby("Element")["Y2018"].sum().reset_index()
hi.columns = [["Element", "Y2018"]]
# hi.sort_values(by = "Y2018", ascending = False)
hi
# Out:
#                                    Element       Y2018
# 0                 Domestic supply quantity  2161167.10
# 1                          Export Quantity   181067.80
# 2       Fat supply quantity (g/capita/day)    10257.21
# 3                                     Feed   233441.68
# 4                                     Food  1303806.28
# 5            Food supply (kcal/capita/day)   455241.00
# 6      Food supply quantity (kg/capita/yr)    49055.02
# 7                          Import Quantity   287736.09
# 8                                   Losses   163902.00
# 9                    Other uses (non-food)    91273.97
# 10                              Processing   308421.00
# 11                              Production  2075025.89
# 12  Protein supply quantity (g/capita/day)    11833.43
# 13                               Residuals    34864.00
# 14                                    Seed    25263.14
# 15                         Stock Variation    20579.91
# ...

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
alg = df[(df.Area) == "Algeria"]
alg.groupby("Element")["Y2018"].sum()
# Out:
# Element
# Domestic supply quantity                  90023.42
# Export Quantity                             809.54
# Fat supply quantity (g/capita/day)          309.09
# Feed                                      10654.00
# Food                                      63736.33
# Food supply (kcal/capita/day)             13288.00
# Food supply quantity (kg/capita/yr)        1509.28
# Import Quantity                           36238.29
# Losses                                     7708.00
# Other uses (non-food)                      3970.08
# Processing                                 2479.00
# Production                                60765.67
# Protein supply quantity (g/capita/day)      367.28
# Residuals                                   630.00
# Seed                                        825.00
# Stock Variation                            6172.00
# Total Population - Both sexes             42228.00
# Name: Y2018, dtype: float64

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
a = df[['Element Code', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']]
print(a["Element Code"].corr(a["Y2014"]))
print(a["Element Code"].corr(a["Y2015"]))
print(a["Element Code"].corr(a["Y2016"]))
print(a["Element Code"].corr(a["Y2017"]))
print(a["Element Code"].corr(a["Y2018"]))
# Out:
# 0.026257087010024112
# 0.025631860410360176
# 0.025080372338308714
# 0.025932344579844665
# 0.025988578712157227
